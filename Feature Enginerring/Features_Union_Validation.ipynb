# %% [markdown]
# <a href="https://colab.research.google.com/github/BlackCurrantDS/ATiML-Project/blob/master/Features_Union_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#Getting data into dataframe from all features
df_meta_train = pd.read_csv("df_meta_validation.csv", index_col=0)
df_meta_train.shape
# Out:
# (11, 26)

# %%
vader_sentiment_train = pd.read_csv("vader_sentiment_validation.csv", index_col=0)
vader_sentiment_train.shape
# Out:
# (11, 6)

# %%
emotions_analysis_train = pd.read_csv("emotions_amalysis_validation.csv", index_col=0)
emotions_analysis_train.shape
# Out:
# (11, 12)

# %%
#Getting data from  training books
books_train = pd.read_csv("books_validation.csv", index_col=0)
books_train = books_train[['FileNo', 'Author_Name', 'Book_Name']]

# %%
data_frames = [df_meta_train,vader_sentiment_train,emotions_analysis_train, books_train]

# %%
#merging all the features
from functools import reduce

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['FileNo']), data_frames).fillna('void')

# %%
df_merged.head(1)
# Out:
#    FileNo  ...                                        Book_Name
# 0   34947  ...  The House of Strange Secrets: A Detective Story
#
# [1 rows x 44 columns]

# %%
df_merged.shape
# Out:
# (11, 44)

# %%
df_merged.drop(['genre_x', 'genre_y' ], axis = 1)
# Out:
#     FileNo  ...                                          Book_Name
# 0    34947  ...    The House of Strange Secrets: A Detective Story
# 1    48297  ...            A Soldier's Daughter- and Other Stories
# 2    27549  ...                                  The Seven Secrets
# 3    16968  ...                               The Bad Man: A Novel
# 4    37081  ...  In Strange Company: A Story of Chili and the S...
# 5     7842  ...                               The Rise of Iskander
# 6    41314  ...       My Danish Sweetheart: A Novel. Volume 2 of 3
# 7    10067  ...  The Mystery of the Boule Cabinet: A Detective ...
# 8    18443  ...                                       Parrot & Co.
# 9    41340  ...                Mount Royal: A Novel. Volume 2 of 3
# 10   32560  ...          Gerald Fitzgerald- the Chevalier: A Novel
#
# [11 rows x 42 columns]

# %%
#df_merged.to_csv("features_train.csv")
df_merged.to_csv("features_validation.csv")
#df_merged.to_csv("features_test.csv")
